# %%
import matplotlib.pyplot as plt

# %%
year=[2001,2002,2003,2004,2005,2006,2007,2008]
salary=[50,100,200,600,1000,1200,1500,2000]
plt.bar(year,salary)
plt.show()

# %%
plt.bar(year,salary,width=0.5,edgecolor='red')
plt.xticks(rotation=40)
plt.show()
