# %%
import pandas as pd

# %%
titan=pd.read_csv("titanic_dataset.csv")
titan.describe()
titan.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titan.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
del titan['Sex']
del titan['SibSp']
del titan['Parch']
del titan['Ticket']
del titan['Fare']
titan.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age Cabin Embarked
# 0                            Braund, Mr. Owen Harris  22.0   NaN        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   C85        C
# 2                             Heikkinen, Miss. Laina  26.0   NaN        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  C123        S
# 4                           Allen, Mr. William Henry  35.0   NaN        S
# 5                                   Moran, Mr. James   NaN   NaN        Q
# 6                            McCarthy, Mr. Timothy J  54.0   E46        S
# ...

# %%
titan.Age.fillna(titan.Age.median(),inplace=True)

# %%
titan.Cabin.fillna('XXX',inplace=True)

# %%
titan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age Cabin Embarked
# 0                              Braund, Mr. Owen Harris  22.0   XXX        S
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   C85        C
# 2                               Heikkinen, Miss. Laina  26.0   XXX        S
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  C123        S
# 4                             Allen, Mr. William Henry  35.0   XXX        S
# ..                                                 ...   ...   ...      ...
# ...

# %%
x=titan[titan.Survived==1].describe()
x
# Out:
#        PassengerId  Survived      Pclass         Age
# count   342.000000     342.0  342.000000  342.000000
# mean    444.368421       1.0    1.950292   28.291433
# std     252.358840       0.0    0.863321   13.764425
# min       2.000000       1.0    1.000000    0.420000
# 25%     250.750000       1.0    1.000000   21.000000
# 50%     439.500000       1.0    2.000000   28.000000
# 75%     651.500000       1.0    3.000000   35.000000
# max     890.000000       1.0    3.000000   80.000000
