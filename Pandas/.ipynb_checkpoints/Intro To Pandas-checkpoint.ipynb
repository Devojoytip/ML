# %% [markdown]
# ## Pandas
# Python Module for Data Manipulation

# %%
import pandas as pd

# %%
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
print(type(iris)) # <class 'pandas.core.frame.DataFrame'>
iris
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df=iris # changes in df makes change in iris
df=iris.copy() # we make a copy of iris

# %%
df.head()
df.head(10)
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa

# %% [markdown]
# ## Setting Col Names

# %%
df.columns=['sl','sw','pl','pw','flower_type']

# %%
print(df.shape) # (row,cols)
print(df.dtypes)
# Out:
# (149, 5)
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# dataframe.col_name for accessing a col
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull()
df.isnull().sum() # lists no of null entries in each col
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %% [markdown]
# ## Changing Values

# %%
df.iloc[1:4,2:4]
# Out:
#     pl   pw
# 1  1.3  0.2
# 2  1.5  0.2
# 3  1.4  0.2

# %%
df.iloc[1:4,2:4]=1

# %% [markdown]
# ## Deleting Rows Using .drop(label,inplace)

# %%
# makes a copy of df without the row labelled n so no change in df
# but the indexing does not change after dropping rows
df.drop(0) 
df.drop(3,inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %% [markdown]
# ## Deleting Rows by index

# %%
print(df.index[0])
print(df.index[3])
print(df.index[4])
# Out:
# 1
# 5
# 6

# %%
df.drop(df.index[3],inplace=True) # del row at idx = 3
df.drop(df.index[[2,3,4]],inplace=True) # del row at idx = 2,3,4
df.head()
# Out:
#      sl   sw   pl   pw  flower_type
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa
# 25  5.0  3.4  1.6  0.4  Iris-setosa
# 26  5.2  3.5  1.5  0.2  Iris-setosa

# %% [markdown]
# ## Passing boolean conditions

# %%
df[df.sl>=5]
df[df.flower_type=='Iris-setosa'].describe()
# Out:
#               sl         sw         pl         pw
# count  27.000000  27.000000  27.000000  27.000000
# mean    4.959259   3.340741   1.462963   0.237037
# std     0.305412   0.379533   0.147148   0.107946
# min     4.400000   2.300000   1.200000   0.100000
# 25%     4.750000   3.100000   1.350000   0.200000
# 50%     5.000000   3.300000   1.500000   0.200000
# 75%     5.150000   3.500000   1.550000   0.250000
# max     5.500000   4.200000   1.900000   0.600000

# %% [markdown]
# ## Adding Rows

# %%
df.loc[0]=[1,2,3,4,'Rose']
# Out:
#      sl   sw   pl   pw  flower_type
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 24  5.0  3.0  1.6  0.2  Iris-setosa
# 25  5.0  3.4  1.6  0.4  Iris-setosa
# 26  5.2  3.5  1.5  0.2  Iris-setosa

# %%
df.head()
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0            Rose

# %%
df.index
df.head()
# Out:
#     5.1  3.5  1.4  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa

# %% [markdown]
# ## Resetting Indexes

# %%
# df.reset_index() does n't make change to df & also adds a new col of prev indexes
# to drop extra col drop=True
df.reset_index(drop=True,inplace=True) 
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.6  3.1  1.5  0.2  Iris-setosa
# 1  4.4  2.9  1.4  0.2  Iris-setosa
# 2  5.4  3.7  1.5  0.2  Iris-setosa
# 3  4.8  3.4  1.6  0.2  Iris-setosa
# 4  4.8  3.0  1.4  0.1  Iris-setosa

# %% [markdown]
# ## Delete Cols

# %% [markdown]
# ## Method - 1

# %%
df.drop('sl',axis=1,inplace=True)
df.head()
# Out:
#     sw   pl   pw  flower_type
# 0  3.1  1.5  0.2  Iris-setosa
# 1  2.9  1.4  0.2  Iris-setosa
# 2  3.7  1.5  0.2  Iris-setosa
# 3  3.4  1.6  0.2  Iris-setosa
# 4  3.0  1.4  0.1  Iris-setosa

# %% [markdown]
# ## Method - 2

# %%
del df['sw']

# %%
df.head()
# Out:
#     pl   pw  flower_type
# 0  1.5  0.2  Iris-setosa
# 1  1.4  0.2  Iris-setosa
# 2  1.5  0.2  Iris-setosa
# 3  1.6  0.2  Iris-setosa
# 4  1.4  0.1  Iris-setosa

# %% [markdown]
# ## Reset df to iris

# %%
df=iris.copy()
df.columns=['sl','sw','pl','pw','flower_type']
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# ## Adding Cols

# %%
df['diff']=df['pl']-df['pw']
df['one']=1
df.describe()
# Out:
#                sl          sw          pl          pw        diff    one
# count  149.000000  149.000000  149.000000  149.000000  149.000000  149.0
# mean     5.848322    3.051007    3.774497    1.205369    2.569128    1.0
# std      0.828594    0.433499    1.759651    0.761292    1.047707    0.0
# min      4.300000    2.000000    1.000000    0.100000    0.800000    1.0
# 25%      5.100000    2.800000    1.600000    0.300000    1.400000    1.0
# 50%      5.800000    3.000000    4.400000    1.300000    2.900000    1.0
# 75%      6.400000    3.300000    5.100000    1.800000    3.300000    1.0
# max      7.900000    4.400000    6.900000    2.500000    4.700000    1.0

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  diff  one
# 0  4.9  3.0  1.4  0.2  Iris-setosa   1.2    1
# 1  4.7  3.2  1.3  0.2  Iris-setosa   1.1    1
# 2  4.6  3.1  1.5  0.2  Iris-setosa   1.3    1
# 3  5.0  3.6  1.4  0.2  Iris-setosa   1.2    1
# 4  5.4  3.9  1.7  0.4  Iris-setosa   1.3    1
